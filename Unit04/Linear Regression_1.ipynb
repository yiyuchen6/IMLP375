# %% [markdown]
# # Linear Regression

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. 線性迴歸基本概念

# %% [markdown]
# #### 直線
#
# $$f(x) = 1.2x + 0.8$$

# %%
#準備 50 個點
#5-0/50 = 0.1 +....
# 0~5線性切割
x = np.linspace(0, 5, 50)
print(x)
# Out:
# [0.         0.10204082 0.20408163 0.30612245 0.40816327 0.51020408
#  0.6122449  0.71428571 0.81632653 0.91836735 1.02040816 1.12244898
#  1.2244898  1.32653061 1.42857143 1.53061224 1.63265306 1.73469388
#  1.83673469 1.93877551 2.04081633 2.14285714 2.24489796 2.34693878
#  2.44897959 2.55102041 2.65306122 2.75510204 2.85714286 2.95918367
#  3.06122449 3.16326531 3.26530612 3.36734694 3.46938776 3.57142857
#  3.67346939 3.7755102  3.87755102 3.97959184 4.08163265 4.18367347
#  4.28571429 4.3877551  4.48979592 4.59183673 4.69387755 4.79591837
#  4.89795918 5.        ]

# %%
y = 1.2*x + 0.8
y
# Out:
# array([0.8       , 0.92244898, 1.04489796, 1.16734694, 1.28979592,
#        1.4122449 , 1.53469388, 1.65714286, 1.77959184, 1.90204082,
#        2.0244898 , 2.14693878, 2.26938776, 2.39183673, 2.51428571,
#        2.63673469, 2.75918367, 2.88163265, 3.00408163, 3.12653061,
#        3.24897959, 3.37142857, 3.49387755, 3.61632653, 3.73877551,
#        3.86122449, 3.98367347, 4.10612245, 4.22857143, 4.35102041,
#        4.47346939, 4.59591837, 4.71836735, 4.84081633, 4.96326531,
#        5.08571429, 5.20816327, 5.33061224, 5.45306122, 5.5755102 ,
#        5.69795918, 5.82040816, 5.94285714, 6.06530612, 6.1877551 ,
#        6.31020408, 6.43265306, 6.55510204, 6.67755102, 6.8       ])

# %%
#畫圖
plt.scatter(x,y)
plt.plot(x, 1.2*x+0.8, 'r')

# %% [markdown]
# #### add noise
#
# $$f(x) + \varepsilon(x)$$

# %%
y = 1.2*x + 0.8 + 0.6*np.random.randn(50)
print(y)
# Out:
# [0.89111298 0.33208935 1.50849289 1.38235043 1.63263088 1.73734779
#  2.18110489 1.71410742 1.38954534 1.83628177 2.42311711 1.48634634
#  2.26488261 2.33833039 3.18857976 2.02021402 3.1767764  3.3267495
#  1.7278248  2.19771143 4.08616612 4.02304963 3.51239759 2.75595026
#  3.50402532 4.69242991 4.84766904 3.65692386 4.47132852 5.41560556
#  4.22820776 4.73684179 4.41450911 4.97669543 5.06878126 4.92935447
#  3.7401348  5.71976997 4.3395625  5.33486344 7.1072315  5.69548598
#  6.03242875 6.47393703 6.57695486 6.86090702 5.79508057 6.35452176
#  5.78561237 6.40358658]

# %%
plt.scatter(x,y)
plt.plot(x, 1.2*x + 0.8, 'r')

# %%
from sklearn.linear_model import LinearRegression
regr = LinearRegression()

# %%
regr
# Out:
# LinearRegression()

# %% [markdown]
# 要求資料轉換<br>
#
# $$[x_1, x_2, \ldots, x_{50}]$$
#
# ==>
#
# $$[[x_1], [x_2], \ldots, [x_{50}]]$$
#
#
# 矩陣的概念

# %%
print(x.shape)
X = x.reshape(-1,1)
X.shape
# Out:
# (50,)
# (50, 1)

# %%
regr.fit(X,y)
# Out:
# LinearRegression()

# %%
Y = regr.predict(X)
print(Y)
# Out:
# [0.91291452 1.03099606 1.14907759 1.26715913 1.38524067 1.5033222
#  1.62140374 1.73948528 1.85756682 1.97564835 2.09372989 2.21181143
#  2.32989296 2.4479745  2.56605604 2.68413758 2.80221911 2.92030065
#  3.03838219 3.15646372 3.27454526 3.3926268  3.51070833 3.62878987
#  3.74687141 3.86495295 3.98303448 4.10111602 4.21919756 4.33727909
#  4.45536063 4.57344217 4.69152371 4.80960524 4.92768678 5.04576832
#  5.16384985 5.28193139 5.40001293 5.51809446 5.636176   5.75425754
#  5.87233908 5.99042061 6.10850215 6.22658369 6.34466522 6.46274676
#  6.5808283  6.69890984]

# %%
#了解你的訓練參數
regr.get_params()
# Out:
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}

# %%
plt.scatter(x, y) #原本 
plt.plot(x, Y, 'ro') #預測
#calculate mse
mse = np.sum((Y-y)**2) / len(y)
print(mse)
# Out:
# 0.3625915496984027

# %%
#Y=WX+b
W=regr.coef_#斜率
W
# Out:
# array([1.15719906])

# %%
b=regr.intercept_ #截距
b
# Out:
# 0.9129145191757613

# %%
Y
# Out:
# array([0.91291452, 1.03099606, 1.14907759, 1.26715913, 1.38524067,
#        1.5033222 , 1.62140374, 1.73948528, 1.85756682, 1.97564835,
#        2.09372989, 2.21181143, 2.32989296, 2.4479745 , 2.56605604,
#        2.68413758, 2.80221911, 2.92030065, 3.03838219, 3.15646372,
#        3.27454526, 3.3926268 , 3.51070833, 3.62878987, 3.74687141,
#        3.86495295, 3.98303448, 4.10111602, 4.21919756, 4.33727909,
#        4.45536063, 4.57344217, 4.69152371, 4.80960524, 4.92768678,
#        5.04576832, 5.16384985, 5.28193139, 5.40001293, 5.51809446,
#        5.636176  , 5.75425754, 5.87233908, 5.99042061, 6.10850215,
#        6.22658369, 6.34466522, 6.46274676, 6.5808283 , 6.69890984])

# %%
#可以將新的x資料帶入算出結果
W*0.81632653+b
# Out:
# array([1.85756682])

# %%
y
# Out:
# array([0.89111298, 0.33208935, 1.50849289, 1.38235043, 1.63263088,
#        1.73734779, 2.18110489, 1.71410742, 1.38954534, 1.83628177,
#        2.42311711, 1.48634634, 2.26488261, 2.33833039, 3.18857976,
#        2.02021402, 3.1767764 , 3.3267495 , 1.7278248 , 2.19771143,
#        4.08616612, 4.02304963, 3.51239759, 2.75595026, 3.50402532,
#        4.69242991, 4.84766904, 3.65692386, 4.47132852, 5.41560556,
#        4.22820776, 4.73684179, 4.41450911, 4.97669543, 5.06878126,
#        4.92935447, 3.7401348 , 5.71976997, 4.3395625 , 5.33486344,
#        7.1072315 , 5.69548598, 6.03242875, 6.47393703, 6.57695486,
#        6.86090702, 5.79508057, 6.35452176, 5.78561237, 6.40358658])
